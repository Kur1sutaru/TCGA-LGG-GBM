# %%
import plotly.express as px
import pandas as pd

# %% [markdown]
# Importing files from **Google** **Drive**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-de7e80aa-3c25-4e13-9f45-63c7e4fe2ec2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-de7e80aa-3c25-4e13-9f45-63c7e4fe2ec2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving lgg-pca.csv to lgg-pca.csv

# %%
df = pd.read_csv('lgg-pca.csv')
print(df)
# Out:
#      Cluster  Integrated Expression  age_at_index  vital_status
# 0          1             -19.000000            39             1
# 1          1              -9.000000            40             1
# 2          1              -8.000000            22             1
# 3          1              -4.000000            39             1
# 4          1             -21.000000            57             1
# ..       ...                    ...           ...           ...
# 513        2              13.606511            32             0
# 514        2              -4.221552            42             0
# 515        2              20.732158            58             0
# 516        2              -4.572942            66             0
# 517        2               1.391036            25             2
#
# [518 rows x 4 columns]

# %%
pd.read_table('lgg-pca.csv')
# Out:
#     Cluster,Integrated Expression,age_at_index,vital_status
# 0                                           1,-19,39,1
# 1                                            1,-9,40,1
# 2                                            1,-8,22,1
# 3                                            1,-4,39,1
# 4                                           1,-21,57,1
# ..                                                 ...
# 513                            2,13.6065109999257,32,0
# 514                           2,-4.22155203033027,42,0
# 515                            2,20.7321577907011,58,0
# 516                           2,-4.57294151071202,66,0
# 517                            2,1.39103584462014,25,2
#
# [518 rows x 1 columns]

# %% [markdown]
# PCA analysis - Cluster  Integrated Expression  age_at_index  vital_status
#
# ---

# %%
df = df
features = ["Cluster", "Integrated Expression", "age_at_index", "vital_status"]

fig = px.scatter_matrix(
    df,
    dimensions=features,
    color="Cluster"
)
fig.update_traces(diagonal_visible=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d79ce779-b2fc-46c6-b0b0-77b3df7cd095" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d79ce779-b2fc-46c6-b0b0-77b3df7cd095")) {
#                     Plotly.newPlot(
#                         'd79ce779-b2fc-46c6-b0b0-77b3df7cd095',
# ...

# %% [markdown]
# "Cluster", "Barcode", "Expression", "age_at_index", "vital_status"

# %%
df = df
fig = px.scatter(df, x="Integrated Expression", y="age_at_index", color="Cluster")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4056431c-cf1e-4e37-97e1-ad1cd074b7f6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4056431c-cf1e-4e37-97e1-ad1cd074b7f6")) {
#                     Plotly.newPlot(
#                         '4056431c-cf1e-4e37-97e1-ad1cd074b7f6',
# ...

# %%
df = df
fig = px.scatter(df, x="Integrated Expression", y="age_at_index", color="Cluster", marginal_y="violin",
           marginal_x="box", trendline="ols", template="simple_white")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="3e4fc37a-95ef-4fc8-af43-1ecd9d36b00f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3e4fc37a-95ef-4fc8-af43-1ecd9d36b00f")) {
#                     Plotly.newPlot(
#                         '3e4fc37a-95ef-4fc8-af43-1ecd9d36b00f',
# ...

# %%
import plotly.express as px
fig = px.scatter_matrix(df, dimensions=df.columns, color='Cluster', title='Scatter Matrix of Features - LGG', height=800)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4b4b99c1-3c26-4479-b786-26c0d49a60f4" class="plotly-graph-div" style="height:800px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4b4b99c1-3c26-4479-b786-26c0d49a60f4")) {
#                     Plotly.newPlot(
#                         '4b4b99c1-3c26-4479-b786-26c0d49a60f4',
# ...

# %%
X = df.drop(['Cluster'], axis=1)
#Normalize
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_normalized = sc.fit_transform(X)
#Principal components
pca = PCA(n_components=3)
components = pca.fit_transform(X_normalized)

# %%
labels = {
str(i): f"PC {i+1} ({var:.1f}%)" 
for i, var in enumerate(pca.explained_variance_ratio_ * 100)
}
fig = px.scatter_matrix(components, labels=labels, dimensions=range(3), color=df['Cluster'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="35950afc-0cef-4132-bf3f-50dca1b9e10d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("35950afc-0cef-4132-bf3f-50dca1b9e10d")) {
#                     Plotly.newPlot(
#                         '35950afc-0cef-4132-bf3f-50dca1b9e10d',
# ...

# %%
pca = PCA(n_components=3)
components = pca.fit_transform(X_normalized)

# %%
var = pca.explained_variance_ratio_.sum()
fig = px.scatter_3d(components, x=0, y=1, z=2, color=df['Cluster'],title=f'Total Explained Variance LGG: {var}',
labels={'0':'PC1', '1':'PC2', '2':'PC3'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="80921b18-5417-4562-8a8d-6998fcc4c65c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("80921b18-5417-4562-8a8d-6998fcc4c65c")) {
#                     Plotly.newPlot(
#                         '80921b18-5417-4562-8a8d-6998fcc4c65c',
# ...
