# %% [markdown]
# <a href="https://colab.research.google.com/github/Kur1sutaru/TCGA-LGG-GBM/blob/master/annotated_heatmaps.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Example of usage -
# tutorial retrieved from <https://matplotlib.org/stable/gallery/images_contours_and_fields/image_annotated_heatmap.html#sphx-glr-gallery-images-contours-and-fields-image-annotated-heatmap-py> March 9th 2021.
#
# ```
# # This is formatted as code
# ```

# %% [markdown]
# substituir o 0.0 por NS - deixar o quadrado branco

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt


vegetables = ["cucumber", "tomato", "lettuce", "asparagus",
              "potato", "wheat", "barley"]
farmers = ["Farmer Joe", "Upland Bros.", "Smith Gardening",
           "Agrifun", "Organiculture", "BioGoods Ltd.", "Cornylee Corp."]

harvest = np.array([[0.8, 2.4, 2.5, 3.9, 0.0, 4.0, 0.0],
                    [2.4, 0.0, 4.0, 1.0, 2.7, 0.0, 0.0],
                    [1.1, 2.4, 0.8, 4.3, 1.9, 4.4, 0.0],
                    [0.6, 0.0, 0.3, 0.0, 3.1, 0.0, 0.0],
                    [0.7, 1.7, 0.6, 2.6, 2.2, 6.2, 0.0],
                    [1.3, 1.2, 0.0, 0.0, 0.0, 3.2, 5.1],
                    [0.1, 2.0, 0.0, 1.4, 0.0, 1.9, 6.3]])


fig, ax = plt.subplots()
im = ax.imshow(harvest)

# We want to show all ticks...
ax.set_xticks(np.arange(len(farmers)))
ax.set_yticks(np.arange(len(vegetables)))
# ... and label them with the respective list entries
ax.set_xticklabels(farmers)
ax.set_yticklabels(vegetables)

# Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

# Loop over data dimensions and create text annotations.
for i in range(len(vegetables)):
    for j in range(len(farmers)):
        text = ax.text(j, i, harvest[i, j],
                       ha="center", va="center", color="w")

ax.set_title("Harvest of local farmers (in tons/year)")
fig.tight_layout()
plt.show()

# %%
genes = ["GLA", "GLB1", "GNPTG", "GNS", "HEXB", "IDUA", "LIPA", "NAGA"]
clusters = ["Cluster 1 LGG", "Cluster 2 LGG", "Cluster 1 GBM", "Cluster 2 GBM"]
values = np.array([[0.0009, ND, ND, ND],
                  [0.001, ND, ND, ND],
                  [0.004, ND, ND, ND],
                  [0.04, ND, ND, ND],
                  [0.001, ND, ND, ND],
                  [0.02, ND, ND, ND],
                  [0.04, ND, ND, ND],
                  [0.01, ND, ND, ND]])
fig, ax = plt.subplots()
im = ax.imshow(values)

# We want to show all ticks...
ax.set_xticks(np.arange(len(clusters)))
ax.set_yticks(np.arange(len(genes)))

# ... and label them with the respective list entries
ax.set_xticklabels(clusters)
ax.set_yticklabels(genes)

# Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

# Loop over data dimensions and create text annotations.
for i in range(len(genes)):
    for j in range(len(clusters)):
        text = ax.text(j, i, values[i, j],
                       ha="center", va="center", color="w")
        
ax.set_title("Expression vs Vital Status per cluster")
fig.tight_layout()
plt.show()

# %%
genes = ["SLC38A9", "FUCA1", "GUSB", "HEXA", "SGSH", "SLC17A5", "SMPD1", "SLC38A9"]
clusters = ["Cluster 1 LGG", "Cluster 2 LGG", "Cluster 1 GBM", "Cluster 2 GBM"]
values = np.array([[0, 0.01, 0, 0],
                  [0, 0, 0.03, 0],
                  [0, 0, 0.008, 0],
                  [0, 0, 0.01, 0],
                  [0, 0, 0.03, 0],
                  [0, 0, 0.04, 0],
                  [0, 0, 0.02, 0],
                  [0, 0, 0, 0.002]])
fig, ax = plt.subplots()
im = ax.imshow(values)

# We want to show all ticks...
ax.set_xticks(np.arange(len(clusters)))
ax.set_yticks(np.arange(len(genes)))

# ... and label them with the respective list entries
ax.set_xticklabels(clusters)
ax.set_yticklabels(genes)

# Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

# Loop over data dimensions and create text annotations.
for i in range(len(genes)):
    for j in range(len(clusters)):
        text = ax.text(j, i, values[i, j],
                       ha="center", va="center", color="w")
        
ax.set_title("Expression vs Vital Status per cluster")
fig.tight_layout()
plt.show()
